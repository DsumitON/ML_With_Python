# %%
#Problem Statement: Given the data set of adv predict sales based on TV,Radio and Newspaper ads

# %%
#Import libs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics  #For evaluation o the model

# %%
#Read Data from Data set
data=pd.read_csv('Advertising.csv')
print(data.head())
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Check linearity
plt.scatter(data['TV'],data['sales'])
plt.xlabel("TV Add Exp")
plt.ylabel("Sales")
plt.show()

# %%
#Data Preprocessing
#Check null values
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
#Segrete Ind and Dep variable
x=data[['TV','radio','newspaper']].values  #Independent Variable(s)
y=data['sales'].values #Dependent Variable
print(x)
# Out:
# [[230.1  37.8  69.2]
#  [ 44.5  39.3  45.1]
#  [ 17.2  45.9  69.3]
#  [151.5  41.3  58.5]
#  [180.8  10.8  58.4]
#  [  8.7  48.9  75. ]
#  [ 57.5  32.8  23.5]
#  [120.2  19.6  11.6]
#  [  8.6   2.1   1. ]
#  [199.8   2.6  21.2]
#  [ 66.1   5.8  24.2]
#  [214.7  24.    4. ]
#  [ 23.8  35.1  65.9]
#  [ 97.5   7.6   7.2]
#  [204.1  32.9  46. ]
#  [195.4  47.7  52.9]
#  [ 67.8  36.6 114. ]
#  [281.4  39.6  55.8]
#  [ 69.2  20.5  18.3]
#  [147.3  23.9  19.1]
#  [218.4  27.7  53.4]
#  [237.4   5.1  23.5]
#  [ 13.2  15.9  49.6]
#  [228.3  16.9  26.2]
#  [ 62.3  12.6  18.3]
#  [262.9   3.5  19.5]
#  [142.9  29.3  12.6]
#  [240.1  16.7  22.9]
#  [248.8  27.1  22.9]
#  [ 70.6  16.   40.8]
#  [292.9  28.3  43.2]
#  [112.9  17.4  38.6]
#  [ 97.2   1.5  30. ]
#  [265.6  20.    0.3]
#  [ 95.7   1.4   7.4]
#  [290.7   4.1   8.5]
#  [266.9  43.8   5. ]
#  [ 74.7  49.4  45.7]
#  [ 43.1  26.7  35.1]
#  [228.   37.7  32. ]
#  [202.5  22.3  31.6]
#  [177.   33.4  38.7]
#  [293.6  27.7   1.8]
# ...

# %%
#Traing the Linear Regression Algo
lin_reg=LinearRegression()  #Creating object of Algo
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
#We got trained model

# %%
#Lets do some predictions
y_pred=lin_reg.predict(x)
print(y_pred)
# Out:
# [20.52397441 12.33785482 12.30767078 17.59782951 13.18867186 12.47834763
#  11.72975995 12.12295317  3.72734086 12.55084872  7.0322992  17.28512918
#  10.57712073  8.82630048 18.43436638 20.81929952 12.82365674 23.22495716
#   9.95168206 14.16607293 18.10076728 14.7405382   6.4891503  16.5459329
#   8.14651887 15.6100386  14.98951429 17.05167344 19.41053803  9.14402389
#  21.6339338  11.3460929   7.63888314 18.86426829  7.57483051 17.00682618
#  23.40590052 15.62347779  9.90868103 20.44761039 16.37766467 17.2959832
#  21.59580326 13.96385684  8.88787996 15.16152314  8.87338673 21.7226299
#  16.26362018  8.1681656  12.63121132  9.33981296 20.66297563 19.94469957
#  20.37443008 21.2926106   8.52771254 12.77458802 21.89805198 18.13348698
#   5.74215558 22.89067208 16.78426073 13.21069202 16.97773556  7.84904532
#   9.01603163 12.0370073  18.97657924 21.10891244 17.77949782 10.62693815
#  10.36684881  9.90298206 17.32931197 11.85832174  4.47758904 13.81190223
# ...

# %%
#Showing Reg Line
plt.scatter(data['TV'],data['sales'])
plt.plot(data['TV'],y_pred,color='red')
plt.xlabel("TV Add Exp")
plt.ylabel("Sales")
plt.show()

# %%
#Coeficients
print(lin_reg.coef_) #b1
print(lin_reg.intercept_) #b0
# Out:
# [ 0.04576465  0.18853002 -0.00103749]
# 2.938889369459412

# %%
#Prediction on unknow Values
TV=1050
Radio=500
newspaper=260
pred_sales=lin_reg.predict([[TV,Radio,newspaper]])
print(pred_sales)
# Out:
# [144.98702737]

# %%
print("Mean squared Error(MSE):",metrics.mean_squared_error(y_pred,y))
print("Root Mean Squared Erro(RMSE):",np.sqrt(metrics.mean_squared_error(y_pred,y)))
print("Accuracy:",100-metrics.mean_squared_error(y_pred,y))
# Out:
# Mean squared Error(MSE): 2.784126314510936
# Root Mean Squared Erro(RMSE): 1.6685701407225697
# Accuracy: 97.21587368548906
